# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.models import Model
from keras.optimizers import Adam
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
import shutil

# %%
def load_gesture_path(directory):
    file_paths = []
    labels = []
    for category in os.listdir(directory):
        category_path = os.path.join(directory, category)
        if os.path.isdir(category_path):
            print(f"Loading category: {category}")
            for filename in os.listdir(category_path):
                if filename.endswith('.npy'):
                    file_paths.append((category, os.path.join(category_path, filename)))
                    labels.append(category)  
    return file_paths, labels

# %%
def copy_files(file_paths, base_dir):
    for category, file_path in file_paths:
        category_dir = os.path.join(base_dir, category)
        if not os.path.exists(category_dir):
            os.makedirs(category_dir)
        shutil.copy(file_path, category_dir)

# %%
gesture_data_path, gesture_label = load_gesture_path('dataset')
print(gesture_data_path)
# Out:
# Loading category: BackGround_falldown
# Loading category: BackGround_MV_809
# Loading category: BackGround_MV_809_pat
# Loading category: BG_Static
# Loading category: falldown
# Loading category: nono
# Loading category: patpat
# Loading category: slowUp
# Loading category: swipeDown
# Loading category: swipeLeft
# Loading category: swipeRight
# Loading category: swipeUp
# [('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_1.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_10.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_11.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_12.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_13.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_14.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_2.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_3.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_4.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_5.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_6.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_7.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_8.npy'), ('BackGround_falldown', 'dataset\\BackGround_falldown\\slice_9.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_1.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_10.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_100.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_101.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_102.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_103.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_104.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_105.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_106.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_107.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_108.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_109.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_11.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_110.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_111.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_112.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_113.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_114.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_115.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_116.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_117.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_118.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_119.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_12.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_120.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_13.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_14.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_15.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_16.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_17.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_18.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_19.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_2.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_20.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_21.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_22.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_23.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_24.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_25.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_26.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_27.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_28.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_29.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_809\\slice_3.npy'), ('BackGround_MV_809', 'dataset\\BackGround_MV_80 ...

# %%
print(gesture_label)
# Out:
# ['background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'background_moving', 'backgrou ...

# %%
train_paths, test_paths, train_labels, test_labels = train_test_split(
    gesture_data_path, gesture_label, test_size=0.1, random_state=42, stratify=gesture_label
)

train_paths, val_paths, train_labels, val_labels = train_test_split(
    train_paths, train_labels, test_size=0.1/0.9, random_state=42, stratify=train_labels
)
copy_files(train_paths, 'traindata_general\\train')
copy_files(val_paths, 'traindata_general\\validation')
copy_files(test_paths, 'traindata_general\\test')
